# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *
from pylab import *

# %% [markdown]
# ### Problem 1 - Comet orbits

# %% [markdown]
# Alternative **a)** Turn this two equations in four of first order:

# %% [markdown]
# $$ f(x) = \frac{dx}{dt} = v_{x} \hspace{1cm} \rightarrow \hspace{1cm} f(v_{x}) = \frac{dv_{x}}{dt} = -GM \frac{x}{r^{3}} $$

# %% [markdown]
# where $\hspace{1cm} r = \sqrt{x^{2} + y^{2}} \hspace{1cm}$ using the same analogy to y:

# %% [markdown]
# $$ f(y) = \frac{dy}{dt} = v_{y} \hspace{1cm} \rightarrow \hspace{1cm} f(v_{y}) = \frac{dv_{y}}{dt} = -GM \frac{y}{r^{3}} $$

# %% [markdown]
# Alternative **b)** Solve the equations and plot the trajetory of the comet.

# %%
def func1(r_array, t):
  G = 6.67e-11
  M = 1.98898e30

  x, y = r_array[0], r_array[1]
  vx, vy = r_array[2], r_array[3]

  r = sqrt(x**2 + y**2)

  fx = vx
  fy = vy

  fvx = -(G*M/r**3)*x
  fvy = -(G*M/r**3)*y

  return np.array([fx, fy, fvx, fvy], float)

def rouge_kutta1(tpoints, r1, func_name):

  x_points, vx_points = [], []
  y_points, vy_points = [], []

  for t in tpoints:
    x_points.append(r1[0])
    y_points.append(r1[1])

    vx_points.append(r1[2])
    vy_points.append(r1[3])

    k1 = h*func_name(r1, t)
    k2 = h*func_name(r1+0.5*k1, t+0.5*h)
    k3 = h*func_name(r1+0.5*k2, t+0.5*h)
    k4 = h*func_name(r1+k3, t+h)

    r1 += (k1+2*k2+2*k3+k4)/6

  return x_points, y_points, vx_points, vy_points

def rk4_passo_unico(r1, t, h):
    k1 = h * func1(r1, t)
    k2 = h * func1(r1 + 0.5*k1, t + 0.5*h)
    k3 = h * func1(r1 + 0.5*k2, t + 0.5*h)
    k4 = h * func1(r1 + k3, t + h)
    return r1 + (k1 + 2*k2 + 2*k3 + k4) / 6

# %% [markdown]
# We chose a slightly larger value of b for show the different orbits of the comet.

# %%
a = 0
b = 4*1e9
N = 1e5
h = (b-a)/N
tpoints = arange(a, b, h)

r1 = array([4e12, 0, 0, 500], float)

x, y, vx, vy = rouge_kutta_10_1(tpoints, r1, func1)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 3))

for i in range(2):
    axs[i].plot(x, y)
    axs[i].plot(0, 0, 'go', markersize=10)
    axs[i].set_xlabel('x distance [m]')

    if i == 1:
        axs[i].set_xlim(-0.2e11, 0.2e11)
        axs[i].set_ylim(-0.2e11, 0.2e11)
        axs[i].set_title('zoom close to the Sun')

    else:
        axs[i].set_title('orbit of the comet')
        axs[i].set_ylabel('y distance [m]')
plt.show()

# %% [markdown]
# Alternative **c)**: we need modify the step $h$ during the run code. The core idea is that, instead of using a fixed step size $h$, the program evaluates the local error at each iteration. If the comet is far from the Sun (where the force is weak), the step size increases to save time. If it is very close to the Sun (where gravity changes sharply), the step size decreases drastically to maintain accuracy.

# %%
a = 0
b = 4*1e9
N = 1e5
h = (b-a)/N
tpoints = arange(a, b, h)

r1 = array([4e12, 0, 0, 500], float)

x, y, vx, vy = rouge_kutta1(tpoints, r1, func1)

# Parâmetros iniciais
t_start = 0
t_end = 4e9
h = 1e5 # Passo inicial aproximado
delta = 1000 / (365.25 * 24 * 3600) # 1 km/ano em m/s

# %%
# Listas para armazenar os resultados
x_points, y_points = [], []
vx_points, vy_points = [], []
t_points, h_points = [], []

r = np.array([4e12, 0, 0, 500], float) # Condições iniciais
t = t_start

# Loop Adaptativo Principal
while t < b:
    # Ajuste para não ultrapassar o tempo final 'b'
    if t + 2*h > b:
        h = (b - t) / 2

    # 1. Dois passos de tamanho h
    r_meio = rk4_passo_unico(r, t, h)
    r1 = rk4_passo_unico(r_meio, t + h, h)

    # 2. Um passo duplo de tamanho 2h
    r2 = rk4_passo_unico(r, t, 2*h)

    # 3. Estimativa do erro local na posição (x e y)
    ex = (r1[0] - r2[0]) / 30
    ey = (r1[1] - r2[1]) / 30
    erro_calculado = sqrt(ex**2 + ey**2)
    
    # Alvo de precisão para a distância percorrida em 2h
    erro_alvo = 2 * h * delta

    # Calcula a razão rho
    if erro_calculado == 0:
        rho = 2.0  # Evita divisão por zero se o erro for nulo
    else:
        rho = erro_alvo / erro_calculado

    # Se a precisão for aceitável (rho >= 1)
    if rho >= 1:
        t += 2 * h
        r = r1  # Avança o estado do cometa
        
        # Guarda as posições e velocidades atuais
        x_points.append(r[0])
        y_points.append(r[1])
        vx_points.append(r[2])
        vy_points.append(r[3])
        t_points.append(t)
        h_points.append(h)
        
        # Aumenta o passo para a próxima iteração
        h *= min(rho**0.25, 2.0)
    else:
        # Se falhou (erro muito grande), rejeita o passo e reduz h
        h *= rho**0.25

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 3))

for i in range(2):
    axs[i].plot(x_points, y_points)
    axs[i].plot(0, 0, 'go', markersize=10)
    axs[i].set_xlabel('x distance [m]')
    
    if i == 1:
        axs[i].set_xlim(-0.2e11, 0.2e11)
        axs[i].set_ylim(-0.2e11, 0.2e11)
        axs[i].set_title('zoom close to the Sun')
    else:
        axs[i].set_title('orbit of the comet')
        axs[i].set_ylabel('y distance [m]')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Problem 2 - EDO solution

# %% [markdown]
# Solve the differential equation below using the **leapfrog** method:

# %% [markdown]
# $$ \frac{d^{2}x}{dt^{2}} = \left(\frac{dx}{dt}\right)^{2} - x - 5$$
#
# $$ \frac{dx}{dt} = v \hspace{1cm} \text{and} \hspace{1cm} \frac{dv}{dt} = v^{2} - x - 5 $$

# %%
def func2(r, t):

  x, v = r[0], r[1]

  fx = v
  fvx = v**2 - x - 5
  return np.array([fx, fvx], float)

def leapfrog_10_2(tpoints, r1, func_name):
    x_points = []
    vx_points = []

    v_half = r1[0] + 0.5 * h * func_name(r1, tpoints[0])[0]

    for t in tpoints:
        x_points.append(r1[0])
        vx_points.append(r1[1])

        r1[0] += h * v_half
        accel = func_name(r1, t + h)[1]
        v_half += h * accel

    return x_points, vx_points

# %%
a = 0
b = 50

N = 1000
h = (b-a)/N

tpoints = arange(a, b, h)

r2 = array([1, 0], float)

x, vx = leapfrog_10_2(tpoints, r2, func2)

plot(tpoints, x)
show()

# %% [markdown]
# ### Problem 3 - Earth orbit

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
G = 6.6738e-11
M = 1.9891e30
m = 5.9722e24

h = 3600
anos = 5
tempo_total = anos * 365 * 24 * 3600 
passos = int(tempo_total / h)

x0, y0 = 1.4710e11, 0.0
vx0, vy0 = 0.0, 3.0287e4

t_array = np.zeros(passos)
x_array = np.zeros(passos)
y_array = np.zeros(passos)
vx_array = np.zeros(passos)
vy_array = np.zeros(passos)

x_array[0], y_array[0] = x0, y0
vx_array[0], vy_array[0] = vx0, vy0

# %%
def aceleracao(x, y):
    r = np.sqrt(x**2 + y**2)
    ax = -G * M * x / r**3
    ay = -G * M * y / r**3
    return ax, ay

# %%
# Equação 8.77
ax0, ay0 = aceleracao(x0, y0)
v_meio_x = vx0 + 0.5 * h * ax0
v_meio_y = vy0 + 0.5 * h * ay0

# Equações 8.78a até 8.78d
for i in range(passos-1):
    t_array[i+1] = (i+1) * h
    
    # (8.78a) Atualiza a posição
    x_array[i+1] = x_array[i] + h * v_meio_x
    y_array[i+1] = y_array[i] + h * v_meio_y
    
    # (8.78b)
    ax_novo, ay_novo = aceleracao(x_array[i+1], y_array[i+1])
    kx = h * ax_novo
    ky = h * ay_novo
    
    # (8.78c)
    vx_array[i+1] = v_meio_x + 0.5 * kx
    vy_array[i+1] = v_meio_y + 0.5 * ky
    
    # (8.78d)
    v_meio_x = v_meio_x + kx
    v_meio_y = v_meio_y + ky

r_mags = np.sqrt(x_array**2 + y_array**2)
v_quadrados = vx_array**2 + vy_array**2

E_potencial = -G * M * m / r_mags
E_cinetica = 0.5 * m * v_quadrados
E_total = E_potencial + E_cinetica

t_dias = t_array / (24 * 3600)

# %%
plt.plot(x_array, y_array, label='Orbit', color='blue')
plt.plot(0, 0, 'go', label='Sun', markersize=10)

plt.title('Earth orbit')
plt.xlabel('x metros')
plt.ylabel('y metros')

plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(t_dias, E_cinetica, label='Energia Cinética ($E_c$)')
plt.plot(t_dias, E_potencial, label='Energia Potencial ($E_p$)')
plt.plot(t_dias, E_total, label='Energia Total ($E_{total}$)', linestyle='--')

plt.title('Energy over time')
plt.xlabel('Tempo (dias)')
plt.ylabel('Energia (Joules)')

plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(t_dias, E_total, color='black')

plt.title('Total energy')
plt.xlabel('Tempo (dias)')
plt.ylabel('Energia Total (Joules)')
plt.grid(True)

plt.show()

# %% [markdown]
# ### Problem 4

# %%
m = 1.0
R = 0.08
rho = 1.22
C = 0.47
g = 9.81
v0 = 100.0
alvo = 200.0
precisao = 0.1

gamma = (np.pi * (R**2) * rho * C) / (2.0 * m)

h = 0.001

# %%
def simular_trajetoria(theta):
    x, y = 0.0, 0.0
    vx = v0 * np.cos(theta)
    vy = v0 * np.sin(theta)
    
    def aceleracao(vx_atual, vy_atual):
        v = np.sqrt(vx_atual**2 + vy_atual**2)
        ax = -gamma * vx_atual * v
        ay = -g - gamma * vy_atual * v
        return ax, ay

    ax, ay = aceleracao(vx, vy)
    v_meio_x = vx + 0.5 * h * ax
    v_meio_y = vy + 0.5 * h * ay
    
    while y >= 0.0:
        x += h * v_meio_x
        y += h * v_meio_y
        
        ax_nova, ay_nova = aceleracao(v_meio_x, v_meio_y)
        kx = h * ax_nova
        ky = h * ay_nova
        
        vx = v_meio_x + 0.5 * kx
        vy = v_meio_y + 0.5 * ky
        
        v_meio_x += kx
        v_meio_y += ky
        
    return x

# %%
theta_min = 0.0
theta_max = np.pi / 4.0

print(f"Ângulo (graus)   Alcance (m)  Erro (m)")
print("-" * 45)

while True:
    theta_teste = (theta_min + theta_max) / 2.0
    alcance_obtido = simular_trajetoria(theta_teste)
    erro = alcance_obtido - alvo
    
    print(f"{np.degrees(theta_teste):<18.4f}{alcance_obtido:<15.2f}{erro:<12.2f}")
    
    if abs(erro) <= precisao:
        angulo_final_graus = np.degrees(theta_teste)
        break

    if erro < 0:
        theta_min = theta_teste
    else:
        theta_max = theta_teste
print("-" * 45)

print(f"Ângulo necessário para o disparo: {angulo_final_graus:.3f}°")
print(f"Distância final calculada: {alcance_obtido:.2f} m")
# Out:
# Ângulo (graus)   Alcance (m)  Erro (m)
# ---------------------------------------------
# 22.5000           228.65         28.65
# 11.2500           174.84         -25.16
# 16.8750           208.15         8.15
# 14.0625           193.48         -6.52
# 15.4687           201.24         1.24
# 14.7656           197.47         -2.53
# 15.1172           199.37         -0.63
# 15.2930           200.31         0.31
# 15.2051           199.84         -0.16
# 15.2490           200.08         0.08
# ---------------------------------------------
# Ângulo necessário para o disparo: 15.249°
# Distância final calculada: 200.08 m
