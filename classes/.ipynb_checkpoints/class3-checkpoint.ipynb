# %% [markdown]
# # Graphs and visualization

# %% [markdown]
# ### Exercise 2.1 Graphs and basic functions
#
# Repita o procedimento acima para obter gráficos das funções cosseno e raiz quadrada, com
# 0 <x<10.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.0, 20.0, 100)
y = np.sqrt(x)
z = np.cos(x)

# %%
plt.figure(figsize=(6,3))
plt.plot(x, y)
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.plot(x, z)
plt.show()

# %% [markdown]
# ### Exercise 2.2 Plotting data from file
#
# Lembre que na aula passada vimos o comando loadtxt do pacote numpy. Use este comando para
# importar dados do arquivo “sunspots.txt” que está no SIGAA. Em seguida use o fatia mento para
# gerar um vetor só com os valores de x e outro só com valores de y. Por exemplo, se você importou
# os dados experimentais para um vetor de nome “dados”, x= dados[:,0] gera um vetor com os
# dados da primeira coluna. Obtenha então um gráfico contendo os dados experimentais. Consulte o
# problema 3.1 para mais informações sobre estes dados.

# %%
import os     # biblioteca para caminhar sobre pastas/arquivos

# %%
os.getcwd()     # verifica onde o notebook atual está
# Out:
# 'C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes'

# %%
os.listdir('C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes')
# Out:
# ['.ipynb_checkpoints', 'class3.ipynb', 'sunspots.txt']

# %%
data = np.loadtxt('C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes\\sunspots.txt')
data
# Out:
# array([[0.000e+00, 5.800e+01],
#        [1.000e+00, 6.260e+01],
#        [2.000e+00, 7.000e+01],
#        ...,
#        [3.140e+03, 2.520e+01],
#        [3.141e+03, 2.350e+01],
#        [3.142e+03, 2.160e+01]])

# %%
x = data[:, 0]     # todos valores (:,) da primeira coluna (,0)
y = data[:, 1]

print(x)
print(y)
# Out:
# [0.000e+00 1.000e+00 2.000e+00 ... 3.140e+03 3.141e+03 3.142e+03]
# [58.  62.6 70.  ... 25.2 23.5 21.6]

# %%
plt.figure(figsize=(6,3))
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Exercise 2.3 Changing the appearance of the curve
#
# Gere novamente os dados para plotar a função seno, mas desta vez use o comando “plot” com as
# seguintes modificações:
#
# a)  plot (x,y,“g--") e b) plot (x,y,“ko").
#
# Nos exemplos acima, a primeira letra indica a cor da curva. As letras permitidas são r, g, b,
# c, m, y, k, w, que correspondem as cores vermelha, verde, azul, ciano, magenta, amarelo, preto e
# branco. As opções mais comuns para a segunda letra são “-” para uma curva contínua, “--” para
# uma curva tracejada, “o” para usar círculos para marcar os pontos e “s” para usar quadrados para
# marcar os pontos.

# %%
x = np.linspace(0.0, 20.0, 100)
y = np.sin(x)

# %%
plt.figure(figsize=(6,3))
plt.plot(x, y, 'g--')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.plot(x, y, 'ko')
plt.show()

# %% [markdown]
# ### Exercise 2.4 Plotting two graphs at the same time
#
# Use o linspace para gerar uma sequência de dados, e em seguida use o comando “plot” para gerar
# umgráfico do seno e um segundo “plot” para gerar um gráfico do cosseno. Só então use o comando
# show(). Repare que as duas funções se encontram no mesmo gráfico. Tente usar as opções da
# função “plot” discutidas no exercício anterior para diferenciar as duas curvas.

# %%
x = np.linspace(0.0, 10.0, 100)
y = np.sin(x)
z = np.cos(x)

# %%
plt.figure(figsize=(6,3))
plt.plot(x, y, 'm--')
plt.plot(x, z, 'c-')
plt.show()

# %% [markdown]
# ### Exercise 2.5 HR Diagram
#
# Baixe do SIGAA o arquivo ‘stars.txt’. A primeira coluna deste arquivo contém valores de tempera
# tura e a segunda de magnitude. Estes dados podem ser usados para plotar um diagrama HR, que é
# bastante usado em estudos de evolução estelar.
#
# a)  Importe o arquivo usando o loadtxt, use fatiamento para obter separar as colunas x e y e faça
# umgráfico dos dados obtidos usando o scatter.
#
# b) Mude olimite da temperatura e da magnitude. Use valores de T entre 0 e 13000 e valores de
# Hentre-5 e 20. Também adicione legendas para os dois eixos. Faça um novo gráfico com o
# scatter.
#
# c)  Diagramas HR são tipicamente plotados “invertidos”, com valores altos de T e H perto da
# origem e valores menores distantes. Para obter um gráfico deste tipo, inverta os limites de T
# e Husados anteriormente. Por exemplo, para a coordenada x use agora “xlim(13000,0)”.

# %%
os.listdir('C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes')
# Out:
# ['.ipynb_checkpoints', 'class3.ipynb', 'stars.txt', 'sunspots.txt']

# %%
stars = np.loadtxt('C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes\\stars.txt')
stars
# Out:
# array([[ 6.83145085e+02,  1.57300000e+01],
#        [ 6.83145085e+02,  1.70100000e+01],
#        [ 1.01283217e+03,  1.58600000e+01],
#        ...,
#        [ 1.27621641e+04, -1.37000000e+00],
#        [ 1.42023258e+04, -2.77000000e+00],
#        [ 1.47860721e+04,  1.04600000e+01]])

# %%
plt.figure(figsize=(5,4))

# a)
temps = stars[:, 0]
mags = stars[:, 1]
plt.scatter(temps, mags, s=1)

# b)
plt.xlim(0, 13000)
plt.ylim(-5, 20)

plt.show()

# %%
plt.figure(figsize=(5,4))
plt.scatter(temps, mags, s=1, c='c')

# c)
plt.xlim(13000, 0)
# Out:
# (13000.0, 0.0)

# %% [markdown]
# ### Exercise 2.6 Density graph
#
# Baixe do SIGAA o arquivo ‘circular.txt’ e importe os dados usando o loadtxt. Observe que
# obtivemos uma matriz de dados. Cada valor da matriz indica o valor local da grandeza que se quer
# plotar (por exemplo, temperatura), e os índices i e j da matriz indicam a posição do ponto. O código
# abaixo gera um gráfico de densidade com este conjunto de dados

# %%
from pylab import imshow, show, bone

# %%
os.listdir('C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes')
# Out:
# ['.ipynb_checkpoints',
#  'circular.txt',
#  'class3.ipynb',
#  'stars.txt',
#  'sunspots.txt']

# %%
circ = np.loadtxt('C:\\Users\\erick\\Downloads\\jupyternotebook\\COMP\\classes\\circular.txt')
circ
# Out:
# array([[ 1.        ,  0.99980001,  0.99920011, ..., -0.8601554 ,
#         -0.84978342, -0.83907153],
#        [ 0.99980001,  0.99960003,  0.99900017, ..., -0.86014516,
#         -0.84977285, -0.83906065],
#        [ 0.99920011,  0.99900017,  0.99840043, ..., -0.86011443,
#         -0.84974116, -0.839028  ],
#        ...,
#        [-0.8601554 , -0.86014516, -0.86011443, ...,  0.05157697,
#          0.03744188,  0.02328514],
#        [-0.84978342, -0.84977285, -0.84974116, ...,  0.03744188,
#          0.02331348,  0.00916625],
#        [-0.83907153, -0.83906065, -0.839028  , ...,  0.02328514,
#          0.00916625, -0.00496866]])

# %%
plt.figure(figsize=(3,3))
imshow(circ, 'viridis')
show()

# %% [markdown]
# Note que a origem do sistema está no canto superior esquerdo. Para entender porque isto ocorre,
# lembre que em uma matriz esta é a posição em que se encontra o termo com i = j = 0. Da mesma
# forma, observe que a posição x de um ponto é dada pelo índice j, uma vez que pontos mais a direita
# em umamatriz possuem valores de j maiores. Similarmente, a posição y de um ponto é dada pelo
# índice i.
#
# a) Altere a posição da origem, de modo que ela se localize no canto inferior esquerdo. Para isto,
# utilize o comando “imshow(dados,origin=”lower”)”.

# %%
plt.figure(figsize=(3,3))
imshow(circ, 'viridis', origin='lower')
show()

# %% [markdown]
# b) Modifique o padrão de cor do gráfico. Para fazer isto, digite uma das seguintes palavras
# depois de usar o comando “imshow()” e antes de usar o comando “show()’: jet(), gray(),
# hot(), spectral(), bone(), hsv(). Antes de usar estes comandos, você deve importar eles do
# pylab.

# %%
plt.figure(figsize=(3,3))
imshow(circ, origin='lower')
bone()
show()

# %% [markdown]
# c) Até o momento, as posições x e y correspondem aos índices i e j de um ponto na ma
# triz de dados. Para alterar isto, use o comando “imshow” com a seguinte modificação
# “imshow(dados,origin=”lower”,extent=[0,10,0,5])”

# %%
imshow(circ, origin='lower', extent=[0,10,0,5])
show()
